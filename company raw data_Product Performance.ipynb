# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from pandas_profiling import ProfileReport

# %%
xls=pd.ExcelFile(r"C:\Users\prash\Downloads\Customer Raw data.xlsx")

# %%
df1=pd.read_excel(xls,'sheet1')
df2=pd.read_excel(xls,'sheet2')
df3=pd.read_excel(xls,'sheet3')
# Out:
# C:\Users\prash\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# C:\Users\prash\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# C:\Users\prash\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
df2
# Out:
#             pId                                  pName  clicks  carts  orders
# 0     CL0034516   Chevron stripe colorblock maxi dress   29144   2181     204
# 1     CL0037085   Chevron stripe colorblock maxi dress   25892    237      70
# 2     CL0036758   Bird print pleated cotton knit dress   16343    340      97
# 3     CL0032310        Cotton knit fit and flare dress   16234    350      99
# 4     CL0037110  Pleat front chambray denim maxi dress   13317    229      56
# ...         ...                                    ...     ...    ...     ...
# 2496  CL0036376                               Name N/A       0      0       1
# 2497  CL0035627        Heart print cotton A-line dress       0      0       1
# 2498  GC0000202                               Name N/A       0      0       5
# 2499  GC0000204                               Name N/A       0      0       7
# 2500  GC0000205                               Name N/A       0      0      11
#
# [2501 rows x 5 columns]

# %%
profile = ProfileReport(df2, title="Pandas Profiling Report")
profile.to_widgets()
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.13.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2022-05-08 09:59:42.504618&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
df2.columns
# Out:
# Index(['pId', 'pName', 'clicks', 'carts', 'orders'], dtype='object')

# %% [markdown]
# # statsics analysis

# %%
# Missing values
df2.isnull().sum()
# Out:
# pId       0
# pName     0
# clicks    0
# carts     0
# orders    0
# dtype: int64

# %% [markdown]
# Observation
# There is no null value

# %%
df2.describe()
# Out:
#              clicks        carts       orders
# count   2501.000000  2501.000000  2501.000000
# mean     544.756497    11.903239     3.166733
# std     1349.562652    52.851750     8.410742
# min        0.000000     0.000000     0.000000
# 25%       29.000000     0.000000     0.000000
# 50%       97.000000     0.000000     0.000000
# 75%      632.000000    12.000000     3.000000
# max    29144.000000  2181.000000   204.000000

# %% [markdown]
# # Observation
#
# Standrd deviation of the clicks are more compare to the carts and orders.  Maximum oder is 205 .

# %%
sns.histplot(df2['orders'],kde=True)
# Out:
# <AxesSubplot:xlabel='orders', ylabel='Count'>

# %%
sns.histplot(df2['clicks'],kde=True)
# Out:
# <AxesSubplot:xlabel='clicks', ylabel='Count'>

# %%
sns.histplot(df2['carts'],kde=True)
# Out:
# <AxesSubplot:xlabel='carts', ylabel='Count'>

# %% [markdown]
# # Observation
#
# clicks , order and carts are not normilly distributed.

# %%
##box plot

sns.boxplot(df2['orders'])
# Out:
# C:\Users\prash\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='orders'>

# %%
sns.boxplot(df2['clicks'])
# Out:
# C:\Users\prash\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='clicks'>

# %%
sns.boxplot(df2['carts'])
# Out:
# C:\Users\prash\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='carts'>

# %% [markdown]
# Oberrvation
# There are outlier in the clicks, order, and cart

# %% [markdown]
# # Histrogrm plot of clicks , order and carts

# %%
df2.hist(figsize=(20,10),color='g',alpha=.5)
# Out:
# array([[<AxesSubplot:title={'center':'clicks'}>,
#         <AxesSubplot:title={'center':'carts'}>],
#        [<AxesSubplot:title={'center':'orders'}>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# # Bar graphs for mean of clicks , order and cart

# %%
click_mean=np.mean(df2['clicks'])
order_mean=np.mean(df2['orders'])
cart_mean=np.mean(df2['carts'])
l1=[]
l1.append(click_mean)
l1.append(order_mean)
l1.append(cart_mean)
l1
l2=["click_mean","order_mean","cart_mean"]

plt.bar(l2,l1)
# Out:
# <BarContainer object of 3 artists>

# %%
df2.plot.scatter(x='clicks',y='orders',s=500)
# Out:
# <AxesSubplot:xlabel='clicks', ylabel='orders'>

# %% [markdown]
# # Observation
# order of the product are concentrated between zero to 10000 click . where product name is given
