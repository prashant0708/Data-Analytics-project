# %% [markdown]
# # Objective: To increase conversions for customers.
# # Question: What would you do keeping in mind that the customer uses this search product? How can you use this data to bring out insights to improve the search product?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from pandas_profiling import ProfileReport

# %%
xls=pd.ExcelFile("C:\\Users\\prash\\Downloads\\EDA\\Networth_Corp_Assignment_Submissio _prashant kumar_ singh\\Customer Raw data.xlsx")

# %%
df1=pd.read_excel(xls,'sheet1')
df1
# Out:
# C:\Users\prash\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#            PID                                   Product Name Category  \
# 0    CL0036386            Ikat stripe print cotton knit dress    Dress
# 1    CL0030567                    Feminine pleated knit dress    Dress
# 2    CL0032320   Floral embellished chambray denim maxi dress    Dress
# 3    CL0036700                     Dot print cap sleeve shirt      Top
# 4    CL0036365          Layered asymmetric hem hacci knit top      Top
# ..         ...                                            ...      ...
# 711  CL0031288                      Ruffle front poplin dress    Dress
# 712  CL0032199              Beaded cotton poplin sheath dress    Dress
# 713  CL0031267          Embellished stripe waist poplin dress    Dress
# 714  CL0031287                        Sash waist poplin skirt    Skirt
# ...

# %% [markdown]
# # 6) You can ignore the initial price and final price from your analysis.
# based on the question , initial price and final price not requried for my analysis

# %%
del df1['Final Price']
del df1['Initial Price']

# %%
df1
# Out:
#            PID                                   Product Name Category  \
# 0    CL0036386            Ikat stripe print cotton knit dress    Dress
# 1    CL0030567                    Feminine pleated knit dress    Dress
# 2    CL0032320   Floral embellished chambray denim maxi dress    Dress
# 3    CL0036700                     Dot print cap sleeve shirt      Top
# 4    CL0036365          Layered asymmetric hem hacci knit top      Top
# ..         ...                                            ...      ...
# 711  CL0031288                      Ruffle front poplin dress    Dress
# 712  CL0032199              Beaded cotton poplin sheath dress    Dress
# 713  CL0031267          Embellished stripe waist poplin dress    Dress
# 714  CL0031287                        Sash waist poplin skirt    Skirt
# 715  CL0031947                  Colorblock retro poplin frock    Dress
#
#                    Color        Primary Color           Fabric
# ...

# %%
profile = ProfileReport(df1, title="Pandas Profiling Report")
profile.to_widgets()
profile.to_file("product_description.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
#finding the colomn in the product description 
df1.columns
# Out:
# Index(['PID', 'Product Name', 'Category', 'Color', 'Primary Color', 'Fabric'], dtype='object')

# %%
##finding the catagorical variable 
for i in df1.columns:
    if df1[i].dtypes=='O':
        print (i)
# Out:
# PID
# Product Name
# Category
# Color
# Primary Color
# Fabric

# %% [markdown]
# # There are 5 catagorical data

# %%
# Missing values
df1.isnull().sum()
# Out:
# PID              0
# Product Name     0
# Category         0
# Color            0
# Primary Color    0
# Fabric           0
# dtype: int64

# %% [markdown]
# # Observation 1
#
# there are no null values

# %%
sns.countplot(df1['Category'])
# Out:
# C:\Users\prash\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %% [markdown]
# # Observation 2
# Dress catagoury has more count.

# %%
df1
# Out:
#            PID                                   Product Name Category  \
# 0    CL0036386            Ikat stripe print cotton knit dress    Dress
# 1    CL0030567                    Feminine pleated knit dress    Dress
# 2    CL0032320   Floral embellished chambray denim maxi dress    Dress
# 3    CL0036700                     Dot print cap sleeve shirt      Top
# 4    CL0036365          Layered asymmetric hem hacci knit top      Top
# ..         ...                                            ...      ...
# 711  CL0031288                      Ruffle front poplin dress    Dress
# 712  CL0032199              Beaded cotton poplin sheath dress    Dress
# 713  CL0031267          Embellished stripe waist poplin dress    Dress
# 714  CL0031287                        Sash waist poplin skirt    Skirt
# 715  CL0031947                  Colorblock retro poplin frock    Dress
#
#                    Color        Primary Color           Fabric
# ...

# %%
##count of category 
df1["Category"].value_counts()
# Out:
#  Dress       428
#  Top         147
#  Skirt        72
#  Pant         49
#  Jumpsuit     11
#  Jacket        9
# Name: Category, dtype: int64

# %% [markdown]
# # observation 3
# Catagory dress has more count hence user has more search Dress.
# jacket has not more demand may be this data is created from summer .

# %%
##count of fabric 
df1["Fabric"].value_counts()
# Out:
#  Cotton                      263
#  Cotton Spandex              139
#  Polyester                   104
#  Polyester Crepe de Chine     43
#  Polyester Spandex            32
#  Viscose Spandex              20
#  Cotton Polyester             17
#  Cotton Polyester Spandex     17
#  Polyamide Spandex            12
#  Rayon Nylon Spandex          12
#  Rayon Polyester Spandex       7
#  Silk                          7
#  Cotton Nylon                  6
#  Rayon                         6
#  Polyester Rayon Spandex       4
#  Polyester Nylon               4
#  Viscose                       4
#  Cotton Rayon Spandex          4
#  Tencel                        3
#  Nylon                         3
#  Nylon Polyester               2
#  Polyester Rayon               2
#  Polyester Metallic            2
#  Nylon Cotton                  1
#  Wool Nylon                    1
#  Cotton Linen                  1
# Name: Fabric, dtype: int64

# %% [markdown]
# # observation 4
# user has serched more cotton dress it is clear that it is the data of summer season if we provide more option in cotton conversation may increase .

# %% [markdown]
# # Reading the data from Product Proformance

# %%
df2=pd.read_excel(xls,'sheet2')
df2
# Out:
# C:\Users\prash\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#             pId                                  pName  clicks  carts  orders
# 0     CL0034516   Chevron stripe colorblock maxi dress   29144   2181     204
# 1     CL0037085   Chevron stripe colorblock maxi dress   25892    237      70
# 2     CL0036758   Bird print pleated cotton knit dress   16343    340      97
# 3     CL0032310        Cotton knit fit and flare dress   16234    350      99
# 4     CL0037110  Pleat front chambray denim maxi dress   13317    229      56
# ...         ...                                    ...     ...    ...     ...
# 2496  CL0036376                               Name N/A       0      0       1
# 2497  CL0035627        Heart print cotton A-line dress       0      0       1
# 2498  GC0000202                               Name N/A       0      0       5
# ...

# %%
##profiling of the product dscription .
profile = ProfileReport(df2, title="Pandas Profiling Report")
profile.to_widgets()
profile.to_file("product_proformance.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
##product proformance click and orders correlation 
clicks=df2["clicks"]
orders=df2["orders"]

correlation = clicks.corr(orders)
correlation
# Out:
# 0.8778497046634236

# %%
sns.regplot(x=df2["clicks"],y=df2["orders"])
# Out:
# <AxesSubplot:xlabel='clicks', ylabel='orders'>

# %% [markdown]
# # observation 5
# correlation cofficient of the clicks and orders is 0.877 which is showing strong correlation hence clicks has impact on the order.
# if we have more number of clicks we can have more orders .

# %%
##product proformance carts and orders correlation 
carts=df2["carts"]
orders=df2["orders"]

correlation = carts.corr(orders)
correlation
# Out:
# 0.8019044616776909

# %% [markdown]
# # observation 6
# correlation cofficient of the carts and orders is 0.80190 which is showing strong correlation hence carts has impact on the order. if we have more number of cart value we can have more orders .

# %%
##product proformance carts and orders correlation 
carts=df2["carts"]
click=df2["clicks"]

correlation = carts.corr(click)
correlation
# Out:
# 0.730533231894646

# %% [markdown]
# # observation 7
# correlation cofficient of the carts and clicks is 0.7305 which is showing positive correlation .

# %% [markdown]
# # for Merging renaming the pid to PID

# %%
df2.rename(columns={'pId':"PID"},inplace=True)
df2
# Out:
#             PID                                  pName  clicks  carts  orders
# 0     CL0034516   Chevron stripe colorblock maxi dress   29144   2181     204
# 1     CL0037085   Chevron stripe colorblock maxi dress   25892    237      70
# 2     CL0036758   Bird print pleated cotton knit dress   16343    340      97
# 3     CL0032310        Cotton knit fit and flare dress   16234    350      99
# 4     CL0037110  Pleat front chambray denim maxi dress   13317    229      56
# ...         ...                                    ...     ...    ...     ...
# 2496  CL0036376                               Name N/A       0      0       1
# 2497  CL0035627        Heart print cotton A-line dress       0      0       1
# 2498  GC0000202                               Name N/A       0      0       5
# 2499  GC0000204                               Name N/A       0      0       7
# 2500  GC0000205                               Name N/A       0      0      11
#
# [2501 rows x 5 columns]

# %% [markdown]
# # merging df1(Product description) and df2(Product proformance Table)

# %%
df = pd.merge(df1, df2, on="PID")

# %%
##deleting the p name from the table
del df['pName']

# %%
df
# Out:
#            PID                                   Product Name Category  \
# 0    CL0036386            Ikat stripe print cotton knit dress    Dress
# 1    CL0030567                    Feminine pleated knit dress    Dress
# 2    CL0032320   Floral embellished chambray denim maxi dress    Dress
# 3    CL0036700                     Dot print cap sleeve shirt      Top
# 4    CL0036365          Layered asymmetric hem hacci knit top      Top
# ..         ...                                            ...      ...
# 711  CL0031288                      Ruffle front poplin dress    Dress
# 712  CL0032199              Beaded cotton poplin sheath dress    Dress
# 713  CL0031267          Embellished stripe waist poplin dress    Dress
# 714  CL0031287                        Sash waist poplin skirt    Skirt
# 715  CL0031947                  Colorblock retro poplin frock    Dress
#
#                    Color        Primary Color           Fabric  \
# ...

# %%
df.describe()
# Out:
#              clicks       carts      orders
# count    716.000000  716.000000  716.000000
# mean    1251.307263   27.124302    7.414804
# std     1756.000433   37.003042   10.478603
# min       14.000000    0.000000    0.000000
# 25%      433.500000    8.000000    2.000000
# 50%      851.000000   17.000000    4.000000
# 75%     1527.000000   32.000000    9.000000
# max    25892.000000  367.000000   97.000000

# %% [markdown]
# # Ploting bar grapth to observe which fabric user has ordered more .

# %%
fig=plt.figure(figsize=(90,50))
plt.rcParams.update({'font.size': 40},)
plt.bar(df['Fabric'],df['orders'])
plt.xlabel("fabric")
plt.ylabel("order")
plt.title("fabric vs order")
plt.xticks(rotation=-45)
plt.show()

# %% [markdown]
# # Observation  8
# user has ordered Cotton Spandex more, if we add more Cotton Spandex product may order frequency increase

# %% [markdown]
# # Ploting bar grapth to observe which fabric user has clicked more .

# %%
fig=plt.figure(figsize=(85,40))
plt.rcParams.update({'font.size':40})
plt.bar(df['Fabric'],df['clicks'])
plt.xlabel('Fabric')
plt.ylabel('clicks')
plt.xticks(rotation=-45)
plt.title('Fabric vs clicks')
# Out:
# Text(0.5, 1.0, 'Fabric vs clicks')

# %% [markdown]
# # Observation 9
#  user has click more on cotton fabric hence preference of user is cotton more

# %%
### bar grapgh of catagory and order to see which category has been order more 
fig=plt.figure(figsize=(20,8))
plt.rcParams.update({"font.size":10})
plt.bar(df['Category'],df['orders'],width=0.4)
plt.xlabel('Catagory')
plt.ylabel('order')
plt.title('Cat vs order')
# Out:
# Text(0.5, 1.0, 'Cat vs order')

# %% [markdown]
# # Observation 10
#
# User has order Dress category more hence if we provide Dress catagory more in user serch converation can increase .

# %%
##Bar graph to check which catagory user has click more .
fig=plt.figure(figsize=(20,8))
plt.rcParams.update({"font.size":10})
plt.bar(df['Category'],df['clicks'],width=0.4)
plt.xlabel('Catagory')
plt.ylabel('clicks')
plt.title('Cat vs clicks')
# Out:
# Text(0.5, 1.0, 'Cat vs clicks')

# %% [markdown]
# # observation 11
# User has click on dress catagory more hecen Dress catagory has more demand .

# %%
##Count operation based on the color
df["Color"].value_counts()
# Out:
#  Black                         39
#  Deep navy                     23
#  Deep indigo                   21
#  Black/white                   18
#  Black multi                   17
#                                ..
#  Red/white                      1
#  Off-white/yellow               1
#  Deep navy/royal blue/white     1
#  Royablue/black                 1
#  Black/spring green             1
# Name: Color, Length: 327, dtype: int64

# %%
##count operation on primary color
df["Primary Color"].value_counts()
# Out:
#  Black                 100
#  White                  59
#  Off-white              56
#  Deep navy              44
#  Deep indigo            29
#                       ...
#  Tiger lily              1
#  Rose smoke              1
#  Light jade green        1
#  Powder blue             1
#  Spring green multi      1
# Name: Primary Color, Length: 122, dtype: int64

# %%
#catagory=df["Category"]
#fabric=df["Fabric"]

catagory=df["Category"].value_counts()
catagory
# Out:
#  Dress       428
#  Top         147
#  Skirt        72
#  Pant         49
#  Jumpsuit     11
#  Jacket        9
# Name: Category, dtype: int64

# %% [markdown]
# # observation 12
# Black color has more count hence user choise of color is Black more .
#
# # Observation 13
#
# Catagory Dress has more count hence user prefer dress more.

# %% [markdown]
# # Observation 14
# Maximum order done on Seagull print pleated cotton knit dress	 which is cotton spandex

# %% [markdown]
# # Filtering the No Name data from main data product proformance sheet 2

# %%
No_name_data=df2.loc[df2["Product Name"]=='Name N/A',: ]
No_name_data
# Out:
#                PID Product Name  clicks  carts  orders
# 790   CL0034516_OS     Name N/A     420      0      12
# 799   CL0035152_OS     Name N/A     405      0       4
# 886   CL0034663_OS     Name N/A     311      0       0
# 904      CL0037242     Name N/A     300      4       1
# 907   CL0032845_OS     Name N/A     297      0       5
# ...            ...          ...     ...    ...     ...
# 2495     CL0036125     Name N/A       0      0       3
# 2496     CL0036376     Name N/A       0      0       1
# 2498     GC0000202     Name N/A       0      0       5
# 2499     GC0000204     Name N/A       0      0       7
# 2500     GC0000205     Name N/A       0      0      11
#
# [1230 rows x 5 columns]

# %% [markdown]
# # Filtering the product which has name

# %%
data_with_name=df2.loc[df2["Product Name"]!='Name N/A',: ]
data_with_name
# Out:
#             PID                                       Product Name  clicks  \
# 0     CL0034516               Chevron stripe colorblock maxi dress   29144
# 1     CL0037085               Chevron stripe colorblock maxi dress   25892
# 2     CL0036758               Bird print pleated cotton knit dress   16343
# 3     CL0032310                    Cotton knit fit and flare dress   16234
# 4     CL0037110              Pleat front chambray denim maxi dress   13317
# ...         ...                                                ...     ...
# 2488  CL0033977                      Faux wrap cotton poplin dress       0
# 2491  CL0033553        Cotton gingham check full skirt-Black/cream       0
# 2492  CL0034512  Embellished stripe sash poplin skirt-Juniper g...       0
# 2493  CL0034755                    Belted polka dot chambray skirt       0
# 2497  CL0035627                    Heart print cotton A-line dress       0
#
#       carts  orders
# 0      2181     204
# 1       237      70
# ...

# %%
No_name_data_mean=np.mean(No_name_data)
No_name_data_mean
# Out:
# C:\Users\prash\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3438: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# C:\Users\prash\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3438: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# clicks    45.372358
# carts      0.016260
# orders     0.231707
# dtype: float64

# %%
data_with_name_mean=np.mean(data_with_name)
data_with_name_mean
# Out:
# clicks    1028.031471
# carts       23.406766
# orders       6.007081
# dtype: float64

# %% [markdown]
# # Observation 15
# From the Above observation it is clear that the product has "no name"  customer has click very less compare to product which has name .
# conversation of "No name " product in cart and order is very low compare to the Product which has name
#
# If supplier replace the "No name" product with product name conversation rate can increase

# %% [markdown]
# # Conclussion
# 1. click has more impact on the orders hence if clicks increase conversation may increase
# 2. carts also has strong correlation with orders .
# 3. Dress category has more count if hence conversation can increase with dress catagory
# 4. Jacket has very low clicks and user preference was more cotton and cotton spandax it show that this data set is of summer or user
#    most preference are cotton dress.
# 5. if No Name product replaced by the Product name conversation rate may increase.
# 6. in Color user preference is Black most hence focusing on the color paramertes also can increase the conversation ration.
